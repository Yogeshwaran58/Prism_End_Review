# %%
import os
import shutil
from pathlib import Path


images_dir = Path(r"C:\content\prism\destination")
json_dir = Path(r"F:\Icon Detection\myvenv\final_annotations\Total")
filtered_json_dir = Path(r"C:\content\prism\destination_json")
filtered_json_dir.mkdir(exist_ok=True)  


for image_file in images_dir.glob("*.jpg"):
    
    json_filename = image_file.stem + '.json'
    source_json_path = json_dir / json_filename
    destination_json_path = filtered_json_dir / json_filename

    
    if source_json_path.exists():
        shutil.copy(source_json_path, destination_json_path)
        print(f"Copied {json_filename} to the filtered JSON directory.")

print("Fetching corresponding JSON files complete.")
# Out:
# Copied 10002.json to the filtered JSON directory.
# Copied 10003.json to the filtered JSON directory.
# Copied 10008.json to the filtered JSON directory.
# Copied 10010.json to the filtered JSON directory.
# Copied 10014.json to the filtered JSON directory.
# Copied 10017.json to the filtered JSON directory.
# Copied 10019.json to the filtered JSON directory.
# Copied 1002.json to the filtered JSON directory.
# Copied 10023.json to the filtered JSON directory.
# Copied 10024.json to the filtered JSON directory.
# Copied 10027.json to the filtered JSON directory.
# Copied 10029.json to the filtered JSON directory.
# Copied 10030.json to the filtered JSON directory.
# Copied 10031.json to the filtered JSON directory.
# Copied 10032.json to the filtered JSON directory.
# Copied 10033.json to the filtered JSON directory.
# Copied 10034.json to the filtered JSON directory.
# Copied 10038.json to the filtered JSON directory.
# Copied 10039.json to the filtered JSON directory.
# ...
